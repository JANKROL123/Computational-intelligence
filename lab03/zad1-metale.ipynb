# %% [markdown]
# ### Importowanie bibliotek

# %%
import pygad
import math

# %% [markdown]
# ### Dane dla algorytmu genetycznego

# %%
gene_space = {"low": 0, "high": 1}
num_genes = 6
sol_per_pop = 15
num_generations = 30
num_parents_mating = 5
keep_parents = 2
parent_selection_type = "sss"
crossover_type = "single_point"
mutation_type = "random"
mutation_percent_genes = 15

# %% [markdown]
# ### Funkcja fitness

# %%
def endurance(chr):
    return math.exp(-2*(chr[1]-math.sin(chr[0]))**2)+math.sin(chr[2]*chr[3])+math.cos(chr[4]*chr[5])
def fitness_func(solution, solution_idx):
    fitness = endurance(solution)
    return fitness
fitness_function = fitness_func

# %% [markdown]
# ### Zdefiniowanie obieku ga_instance

# %%
ga_instance = pygad.GA(gene_space=gene_space,
    num_generations=num_generations,
    num_parents_mating=num_parents_mating,
    fitness_func=fitness_function,
    sol_per_pop=sol_per_pop,
    num_genes=num_genes,
    parent_selection_type=parent_selection_type,
    keep_parents=keep_parents,
    crossover_type=crossover_type,
    mutation_type=mutation_type,
    mutation_percent_genes=mutation_percent_genes
)
# Out:
# /home/jan/.local/lib/python3.10/site-packages/pygad/pygad.py:522: UserWarning: The percentage of genes to mutate (mutation_percent_genes=15) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   if not self.suppress_warnings: warnings.warn("The percentage of genes to mutate (mutation_percent_genes={mutation_percent}) resutled in selecting ({mutation_num}) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).\nIf you do not want to mutate any gene, please set mutation_type=None.".format(mutation_percent=mutation_percent_genes, mutation_num=mutation_num_genes))

# %% [markdown]
# ### Uruchomienie algorytmu

# %%
ga_instance.run()

# %% [markdown]
# ### Wyniki

# %%
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print(solution)
print(f"Fitness: {solution_fitness}")
# Out:
# [0.35166106 0.32425829 0.99593296 0.98274993 0.25548678 0.09195202]
# Fitness: 2.8287105120908866

# %% [markdown]
# ### Wykres

# %%
ga_instance.plot_fitness()
